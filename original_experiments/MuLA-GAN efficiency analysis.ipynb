# %%
from google.colab import drive # Added

# --- Mount Google Drive ---
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Runtime: GPU (Colab > Runtime > Change runtime type > GPU)
# !nvidia-smi
# !python --version

# Install once
# !pip -q install thop pandas
# Out:
# Sat Nov  8 13:03:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Python 3.12.12

# %%
# !pip install ptflops
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from ptflops) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->ptflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->ptflops) (3.0.3)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: ptflops
# Successfully installed ptflops-0.7.5

# %%
import torch
import torch.nn as nn

# %%
def conv(in_channels, out_channels, kernel_size, bias=False, padding = 1, stride = 1):
    return nn.Conv2d(in_channels, out_channels, kernel_size,
        padding=(kernel_size//2), bias=bias, stride=stride)

class BasicConv(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride=1, padding=0, dilation=1, groups=1, relu=True, bn=False, bias=False):
        super().__init__()
        self.out_channels = out_planes
        self.conv = nn.Conv2d(in_planes, out_planes, kernel_size=kernel_size, stride=stride, padding=padding, dilation=dilation, groups=groups, bias=bias)
        self.bn = nn.BatchNorm2d(out_planes, eps=1e-5, momentum=0.01, affine=True) if bn else None
        self.relu = nn.ReLU() if relu else None
    def forward(self, x):
        x = self.conv(x)
        if self.bn is not None: x = self.bn(x)
        if self.relu is not None: x = self.relu(x)
        return x

class ChannelPool(nn.Module):
    def forward(self, x):
        import torch
        return torch.cat((torch.max(x,1)[0].unsqueeze(1), torch.mean(x,1).unsqueeze(1)), dim=1)

class spatial_attn_layer(nn.Module):
    def __init__(self, kernel_size=5):
        super().__init__()
        self.compress = ChannelPool()
        self.spatial = BasicConv(2, 1, kernel_size, stride=1, padding=(kernel_size-1)//2, relu=False)
    def forward(self, x):
        import torch
        x_compress = self.compress(x)
        x_out = self.spatial(x_compress)
        scale = torch.sigmoid(x_out)
        return x * scale

class ca_layer(nn.Module):
    def __init__(self, channel, reduction=8, bias=True):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.conv_du = nn.Sequential(
            nn.Conv2d(channel, channel // reduction, 1, padding=0, bias=bias),
            nn.ReLU(inplace=True),
            nn.Conv2d(channel // reduction, channel, 1, padding=0, bias=bias),
            nn.Sigmoid()
        )
    def forward(self, x):
        y = self.avg_pool(x)
        y = self.conv_du(y)
        return x * y

class SCA(nn.Module):
    def __init__(self, n_feat, kernel_size=3, reduction=8, bias=False, bn=False, act=nn.PReLU(), res_scale=1):
        super().__init__()
        self.body = nn.Sequential(conv(n_feat, n_feat, kernel_size, bias=bias), act, conv(n_feat, n_feat, kernel_size, bias=bias))
        self.SA = spatial_attn_layer()
        self.CA = ca_layer(n_feat, reduction, bias=bias)
        self.conv1x1 = nn.Conv2d(n_feat*2, n_feat, kernel_size=1, bias=bias)
    def forward(self, x):
        import torch
        res = self.body(x)
        sa_branch = self.SA(res)
        ca_branch = self.CA(res)
        res = torch.cat([sa_branch, ca_branch], dim=1)
        res = self.conv1x1(res)
        res += x
        return res

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1),
            nn.BatchNorm2d(out_channels),
        )
    def forward(self, x): return x + self.conv_block(x)

class UNetDown(nn.Module):
    def __init__(self, in_size, out_size, bn=True):
        super().__init__()
        layers = [nn.Conv2d(in_size, out_size, 4, 2, 1, bias=False)]
        if bn: layers.append(nn.BatchNorm2d(out_size, momentum=0.8))
        layers.append(nn.LeakyReLU(0.2))
        layers.append(ResidualBlock(out_size, out_size))
        self.model = nn.Sequential(*layers)
    def forward(self, x): return self.model(x)

class UNetUp(nn.Module):
    def __init__(self, in_size, out_size):
        super().__init__()
        layers = [
            nn.ConvTranspose2d(in_size, out_size, 4, 2, 1, bias=False),
            nn.BatchNorm2d(out_size, momentum=0.8),
            nn.ReLU(inplace=True),
        ]
        layers.append(ResidualBlock(out_size, out_size))
        self.model = nn.Sequential(*layers)
    def forward(self, x, skip_input):
        import torch
        x = self.model(x)
        x = torch.cat((x, skip_input), 1)
        return x

class MuLA_GAN_Generator(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super().__init__()
        self.down1 = UNetDown(in_channels, 32, bn=False)
        self.down2 = UNetDown(32, 128)
        self.down3 = UNetDown(128, 256)
        self.down4 = UNetDown(256, 256)
        self.down5 = UNetDown(256, 256, bn=False)
        self.attention1 = SCA(32)
        self.attention2 = SCA(128)
        self.attention3 = SCA(256)
        self.attention4 = SCA(256)
        self.up1 = UNetUp(256, 256)
        self.up2 = UNetUp(512, 256)
        self.up3 = UNetUp(512, 128)
        self.up4 = UNetUp(256, 32)
        self.final = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.ZeroPad2d((1, 0, 1, 0)),
            nn.Conv2d(64, out_channels, 4, padding=1),
            nn.Tanh(),
        )
    def forward(self, x):
        d1 = self.down1(x); d1 = self.attention1(d1)
        d2 = self.down2(d1); d2 = self.attention2(d2)
        d3 = self.down3(d2); d3 = self.attention3(d3)
        d4 = self.down4(d3); d4 = self.attention4(d4)
        d5 = self.down5(d4)
        u1 = self.up1(d5, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        return self.final(u4)

# %%
model = MuLA_GAN_Generator().eval()

ckpt_path = "/content/drive/MyDrive/EUVP_merged/generator_300_UFO120.pth"  # <--- your path
state = torch.load(ckpt_path, map_location="cpu")

# Remove 'module.' prefix if it exists
state = {k.replace("module.", ""): v for k,v in state.items()}

model.load_state_dict(state, strict=True)
print("✅ Weights loaded")
# Out:
# ✅ Weights loaded

# %%
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device).eval()

x = torch.randn(1, 3, 256, 256).to(device)

# warm-up
for _ in range(10):
    _ = model(x)
torch.cuda.synchronize() if device.type == "cuda" else None

# measure
start = time.time()
for _ in range(50):
    _ = model(x)
torch.cuda.synchronize() if device.type == "cuda" else None
end = time.time()

lat = (end-start)/50
print(f"⏱ Latency: {lat*1000:.2f} ms/image")
print(f"⚡ Throughput: {1/lat:.2f} images/sec")
# Out:
# ⏱ Latency: 9.46 ms/image
# ⚡ Throughput: 105.67 images/sec

# %%
import copy

def replace_prelu_with_relu(m):
    import torch.nn as nn
    for name, module in m.named_children():
        if isinstance(module, nn.PReLU):
            setattr(m, name, nn.ReLU())
        else:
            replace_prelu_with_relu(module)
    return m

model_for_flops = replace_prelu_with_relu(copy.deepcopy(model.cpu())).eval()

# %%
from ptflops import get_model_complexity_info

with torch.no_grad():
    flops, params = get_model_complexity_info(
        model_for_flops,
        (3, 256, 256),
        verbose=False
    )

print("📌 Parameters:", params)
print("📌 FLOPs:", flops)
# Out:
# MuLA_GAN_Generator(
#   16.56 M, 100.000% Params, 13.09 GMac, 99.915% MACs,
#   (down1): UNetDown(
#     20.16 k, 0.122% Params, 331.35 MMac, 2.530% MACs,
#     (model): Sequential(
#       20.16 k, 0.122% Params, 331.35 MMac, 2.530% MACs,
#       (0): Conv2d(1.54 k, 0.009% Params, 25.17 MMac, 0.192% MACs, 3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, negative_slope=0.2)
#       (2): ResidualBlock(
#         18.62 k, 0.112% Params, 305.66 MMac, 2.334% MACs,
#         (conv_block): Sequential(
#           18.62 k, 0.112% Params, 305.66 MMac, 2.334% MACs,
#           (0): Conv2d(9.25 k, 0.056% Params, 151.52 MMac, 1.157% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, 0.000% Params, 1.05 MMac, 0.008% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#           (3): Conv2d(9.25 k, 0.056% Params, 151.52 MMac, 1.157% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, 0.000% Params, 1.05 MMac, 0.008% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (down2): UNetDown(
#     361.47 k, 2.183% Params, 1.48 GMac, 11.311% MACs,
#     (model): Sequential(
#       361.47 k, 2.183% Params, 1.48 GMac, 11.311% MACs,
#       (0): Conv2d(65.54 k, 0.396% Params, 268.44 MMac, 2.049% MACs, 32, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): LeakyReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, negative_slope=0.2)
#       (3): ResidualBlock(
#         295.68 k, 1.785% Params, 1.21 GMac, 9.250% MACs,
#         (conv_block): Sequential(
#           295.68 k, 1.785% Params, 1.21 GMac, 9.250% MACs,
#           (0): Conv2d(147.58 k, 0.891% Params, 604.5 MMac, 4.615% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#           (3): Conv2d(147.58 k, 0.891% Params, 604.5 MMac, 4.615% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (down3): UNetDown(
#     1.71 M, 10.301% Params, 1.75 GMac, 13.341% MACs,
#     (model): Sequential(
#       1.71 M, 10.301% Params, 1.75 GMac, 13.341% MACs,
#       (0): Conv2d(524.29 k, 3.166% Params, 536.87 MMac, 4.099% MACs, 128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): LeakyReLU(0, 0.000% Params, 262.14 KMac, 0.002% MACs, negative_slope=0.2)
#       (3): ResidualBlock(
#         1.18 M, 7.132% Params, 1.21 GMac, 9.236% MACs,
#         (conv_block): Sequential(
#           1.18 M, 7.132% Params, 1.21 GMac, 9.236% MACs,
#           (0): Conv2d(590.08 k, 3.563% Params, 604.24 MMac, 4.613% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 262.14 KMac, 0.002% MACs, inplace=True)
#           (3): Conv2d(590.08 k, 3.563% Params, 604.24 MMac, 4.613% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (down4): UNetDown(
#     2.23 M, 13.467% Params, 571.08 MMac, 4.360% MACs,
#     (model): Sequential(
#       2.23 M, 13.467% Params, 571.08 MMac, 4.360% MACs,
#       (0): Conv2d(1.05 M, 6.332% Params, 268.44 MMac, 2.049% MACs, 256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): LeakyReLU(0, 0.000% Params, 65.54 KMac, 0.001% MACs, negative_slope=0.2)
#       (3): ResidualBlock(
#         1.18 M, 7.132% Params, 302.45 MMac, 2.309% MACs,
#         (conv_block): Sequential(
#           1.18 M, 7.132% Params, 302.45 MMac, 2.309% MACs,
#           (0): Conv2d(590.08 k, 3.563% Params, 151.06 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 65.54 KMac, 0.001% MACs, inplace=True)
#           (3): Conv2d(590.08 k, 3.563% Params, 151.06 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (down5): UNetDown(
#     2.23 M, 13.464% Params, 142.74 MMac, 1.090% MACs,
#     (model): Sequential(
#       2.23 M, 13.464% Params, 142.74 MMac, 1.090% MACs,
#       (0): Conv2d(1.05 M, 6.332% Params, 67.11 MMac, 0.512% MACs, 256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(0, 0.000% Params, 16.38 KMac, 0.000% MACs, negative_slope=0.2)
#       (2): ResidualBlock(
#         1.18 M, 7.132% Params, 75.61 MMac, 0.577% MACs,
#         (conv_block): Sequential(
#           1.18 M, 7.132% Params, 75.61 MMac, 0.577% MACs,
#           (0): Conv2d(590.08 k, 3.563% Params, 37.77 MMac, 0.288% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, 0.003% Params, 32.77 KMac, 0.000% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 16.38 KMac, 0.000% MACs, inplace=True)
#           (3): Conv2d(590.08 k, 3.563% Params, 37.77 MMac, 0.288% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, 0.003% Params, 32.77 KMac, 0.000% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (attention1): SCA(
#     20.79 k, 0.126% Params, 337.41 MMac, 2.576% MACs,
#     (body): Sequential(
#       18.43 k, 0.111% Params, 302.51 MMac, 2.310% MACs,
#       (0): Conv2d(9.22 k, 0.056% Params, 150.99 MMac, 1.153% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, )
#       (2): Conv2d(9.22 k, 0.056% Params, 150.99 MMac, 1.153% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (SA): spatial_attn_layer(
#       50, 0.000% Params, 819.2 KMac, 0.006% MACs,
#       (compress): ChannelPool(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (spatial): BasicConv(
#         50, 0.000% Params, 819.2 KMac, 0.006% MACs,
#         (conv): Conv2d(50, 0.000% Params, 819.2 KMac, 0.006% MACs, 2, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       )
#     )
#     (CA): ca_layer(
#       256, 0.002% Params, 524.55 KMac, 0.004% MACs,
#       (avg_pool): AdaptiveAvgPool2d(0, 0.000% Params, 524.29 KMac, 0.004% MACs, output_size=1)
#       (conv_du): Sequential(
#         256, 0.002% Params, 260.0 Mac, 0.000% MACs,
#         (0): Conv2d(128, 0.001% Params, 128.0 Mac, 0.000% MACs, 32, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(0, 0.000% Params, 4.0 Mac, 0.000% MACs, inplace=True)
#         (2): Conv2d(128, 0.001% Params, 128.0 Mac, 0.000% MACs, 4, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#     (conv1x1): Conv2d(2.05 k, 0.012% Params, 33.55 MMac, 0.256% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (attention2): SCA(
#     331.83 k, 2.004% Params, 1.34 GMac, 10.256% MACs,
#     (body): Sequential(
#       294.91 k, 1.781% Params, 1.21 GMac, 9.226% MACs,
#       (0): Conv2d(147.46 k, 0.890% Params, 603.98 MMac, 4.611% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, )
#       (2): Conv2d(147.46 k, 0.890% Params, 603.98 MMac, 4.611% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (SA): spatial_attn_layer(
#       50, 0.000% Params, 204.8 KMac, 0.002% MACs,
#       (compress): ChannelPool(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (spatial): BasicConv(
#         50, 0.000% Params, 204.8 KMac, 0.002% MACs,
#         (conv): Conv2d(50, 0.000% Params, 204.8 KMac, 0.002% MACs, 2, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       )
#     )
#     (CA): ca_layer(
#       4.1 k, 0.025% Params, 528.4 KMac, 0.004% MACs,
#       (avg_pool): AdaptiveAvgPool2d(0, 0.000% Params, 524.29 KMac, 0.004% MACs, output_size=1)
#       (conv_du): Sequential(
#         4.1 k, 0.025% Params, 4.11 KMac, 0.000% MACs,
#         (0): Conv2d(2.05 k, 0.012% Params, 2.05 KMac, 0.000% MACs, 128, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(0, 0.000% Params, 16.0 Mac, 0.000% MACs, inplace=True)
#         (2): Conv2d(2.05 k, 0.012% Params, 2.05 KMac, 0.000% MACs, 16, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#     (conv1x1): Conv2d(32.77 k, 0.198% Params, 134.22 MMac, 1.025% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (attention3): SCA(
#     1.33 M, 8.014% Params, 1.34 GMac, 10.251% MACs,
#     (body): Sequential(
#       1.18 M, 7.123% Params, 1.21 GMac, 9.224% MACs,
#       (0): Conv2d(589.82 k, 3.562% Params, 603.98 MMac, 4.611% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(0, 0.000% Params, 262.14 KMac, 0.002% MACs, )
#       (2): Conv2d(589.82 k, 3.562% Params, 603.98 MMac, 4.611% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (SA): spatial_attn_layer(
#       50, 0.000% Params, 51.2 KMac, 0.000% MACs,
#       (compress): ChannelPool(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (spatial): BasicConv(
#         50, 0.000% Params, 51.2 KMac, 0.000% MACs,
#         (conv): Conv2d(50, 0.000% Params, 51.2 KMac, 0.000% MACs, 2, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       )
#     )
#     (CA): ca_layer(
#       16.38 k, 0.099% Params, 278.56 KMac, 0.002% MACs,
#       (avg_pool): AdaptiveAvgPool2d(0, 0.000% Params, 262.14 KMac, 0.002% MACs, output_size=1)
#       (conv_du): Sequential(
#         16.38 k, 0.099% Params, 16.42 KMac, 0.000% MACs,
#         (0): Conv2d(8.19 k, 0.049% Params, 8.19 KMac, 0.000% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#         (2): Conv2d(8.19 k, 0.049% Params, 8.19 KMac, 0.000% MACs, 32, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#     (conv1x1): Conv2d(131.07 k, 0.791% Params, 134.22 MMac, 1.025% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (attention4): SCA(
#     1.33 M, 8.014% Params, 335.7 MMac, 2.563% MACs,
#     (body): Sequential(
#       1.18 M, 7.123% Params, 302.06 MMac, 2.306% MACs,
#       (0): Conv2d(589.82 k, 3.562% Params, 150.99 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(0, 0.000% Params, 65.54 KMac, 0.001% MACs, )
#       (2): Conv2d(589.82 k, 3.562% Params, 150.99 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (SA): spatial_attn_layer(
#       50, 0.000% Params, 12.8 KMac, 0.000% MACs,
#       (compress): ChannelPool(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (spatial): BasicConv(
#         50, 0.000% Params, 12.8 KMac, 0.000% MACs,
#         (conv): Conv2d(50, 0.000% Params, 12.8 KMac, 0.000% MACs, 2, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       )
#     )
#     (CA): ca_layer(
#       16.38 k, 0.099% Params, 81.95 KMac, 0.001% MACs,
#       (avg_pool): AdaptiveAvgPool2d(0, 0.000% Params, 65.54 KMac, 0.001% MACs, output_size=1)
#       (conv_du): Sequential(
#         16.38 k, 0.099% Params, 16.42 KMac, 0.000% MACs,
#         (0): Conv2d(8.19 k, 0.049% Params, 8.19 KMac, 0.000% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#         (2): Conv2d(8.19 k, 0.049% Params, 8.19 KMac, 0.000% MACs, 32, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#     (conv1x1): Conv2d(131.07 k, 0.791% Params, 33.55 MMac, 0.256% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (up1): UNetUp(
#     2.23 M, 13.467% Params, 369.75 MMac, 2.823% MACs,
#     (model): Sequential(
#       2.23 M, 13.467% Params, 369.75 MMac, 2.823% MACs,
#       (0): ConvTranspose2d(1.05 M, 6.332% Params, 67.11 MMac, 0.512% MACs, 256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): ReLU(0, 0.000% Params, 65.54 KMac, 0.001% MACs, inplace=True)
#       (3): ResidualBlock(
#         1.18 M, 7.132% Params, 302.45 MMac, 2.309% MACs,
#         (conv_block): Sequential(
#           1.18 M, 7.132% Params, 302.45 MMac, 2.309% MACs,
#           (0): Conv2d(590.08 k, 3.563% Params, 151.06 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 65.54 KMac, 0.001% MACs, inplace=True)
#           (3): Conv2d(590.08 k, 3.563% Params, 151.06 MMac, 1.153% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, 0.003% Params, 131.07 KMac, 0.001% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (up2): UNetUp(
#     3.28 M, 19.799% Params, 1.75 GMac, 13.341% MACs,
#     (model): Sequential(
#       3.28 M, 19.799% Params, 1.75 GMac, 13.341% MACs,
#       (0): ConvTranspose2d(2.1 M, 12.663% Params, 536.87 MMac, 4.099% MACs, 512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): ReLU(0, 0.000% Params, 262.14 KMac, 0.002% MACs, inplace=True)
#       (3): ResidualBlock(
#         1.18 M, 7.132% Params, 1.21 GMac, 9.236% MACs,
#         (conv_block): Sequential(
#           1.18 M, 7.132% Params, 1.21 GMac, 9.236% MACs,
#           (0): Conv2d(590.08 k, 3.563% Params, 604.24 MMac, 4.613% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 262.14 KMac, 0.002% MACs, inplace=True)
#           (3): Conv2d(590.08 k, 3.563% Params, 604.24 MMac, 4.613% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, 0.003% Params, 524.29 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (up3): UNetUp(
#     1.34 M, 8.119% Params, 2.29 GMac, 17.459% MACs,
#     (model): Sequential(
#       1.34 M, 8.119% Params, 2.29 GMac, 17.459% MACs,
#       (0): ConvTranspose2d(1.05 M, 6.332% Params, 1.07 GMac, 8.197% MACs, 512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#       (3): ResidualBlock(
#         295.68 k, 1.785% Params, 1.21 GMac, 9.250% MACs,
#         (conv_block): Sequential(
#           295.68 k, 1.785% Params, 1.21 GMac, 9.250% MACs,
#           (0): Conv2d(147.58 k, 0.891% Params, 604.5 MMac, 4.615% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#           (3): Conv2d(147.58 k, 0.891% Params, 604.5 MMac, 4.615% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, 0.002% Params, 1.05 MMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (up4): UNetUp(
#     149.76 k, 0.904% Params, 844.1 MMac, 6.444% MACs,
#     (model): Sequential(
#       149.76 k, 0.904% Params, 844.1 MMac, 6.444% MACs,
#       (0): ConvTranspose2d(131.07 k, 0.791% Params, 536.87 MMac, 4.099% MACs, 256, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, 0.000% Params, 1.05 MMac, 0.008% MACs, 32, eps=1e-05, momentum=0.8, affine=True, track_running_stats=True)
#       (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#       (3): ResidualBlock(
#         18.62 k, 0.112% Params, 305.66 MMac, 2.334% MACs,
#         (conv_block): Sequential(
#           18.62 k, 0.112% Params, 305.66 MMac, 2.334% MACs,
#           (0): Conv2d(9.25 k, 0.056% Params, 151.52 MMac, 1.157% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, 0.000% Params, 1.05 MMac, 0.008% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(0, 0.000% Params, 524.29 KMac, 0.004% MACs, inplace=True)
#           (3): Conv2d(9.25 k, 0.056% Params, 151.52 MMac, 1.157% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, 0.000% Params, 1.05 MMac, 0.008% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (final): Sequential(
#     3.08 k, 0.019% Params, 205.72 MMac, 1.571% MACs,
#     (0): Upsample(0, 0.000% Params, 4.19 MMac, 0.032% MACs, scale_factor=2.0, mode='nearest')
#     (1): ZeroPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 0, 1, 0))
#     (2): Conv2d(3.08 k, 0.019% Params, 201.52 MMac, 1.539% MACs, 64, 3, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     (3): Tanh(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   )
# )
# 📌 Parameters: 16.56 M
# 📌 FLOPs: 13.1 GMac
