# %%
# 1. Clone the repository
# !git clone https://github.com/AhsanBaidar/MuLA_GAN.git

# 2. Navigate into the folder
# %cd MuLA_GAN

# 3. Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'MuLA_GAN'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 125 (delta 30), reused 78 (delta 15), pack-reused 28 (from 1)
# Receiving objects: 100% (125/125), 144.94 MiB | 34.59 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/MuLA_GAN
# Mounted at /content/drive

# %%
# %%writefile utils/data_utils.py
import os
import glob
import random
import numpy as np
from PIL import Image
import torch
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import yaml

class Dataloader(Dataset):
    def __init__(self, root, dataset_name, transforms_=None, config_path="configs/train_MuLA-GAN.yaml"):
        self.transform = transforms.Compose(transforms_)
        try:
            with open(config_path) as f:
                cfg = yaml.load(f, Loader=yaml.FullLoader)
            input_folder_rel = cfg.get("TRAIN_INPUT", 'train/trainA')
            gt_folder_rel = cfg.get("TRAIN_GT", 'train/trainB')
            base_path = cfg.get("dataset_path", root)
        except Exception as e:
            print(f"Error reading config file {config_path} in Dataloader: {e}")
            raise FileNotFoundError(f"Could not read/parse paths from {config_path}")

        input_path = os.path.join(base_path, input_folder_rel)
        gt_path = os.path.join(base_path, gt_folder_rel)

        print("--- Dataloader Init ---")
        print(f"Base Path (from config): {base_path}")
        print(f"Constructed Input Path: {input_path}")
        print(f"Constructed GT Path: {gt_path}")

        self.filesA = sorted(glob.glob(input_path + "/*.*"))
        self.filesB = sorted(glob.glob(gt_path + "/*.*"))

        print(f"Found {len(self.filesA)} input files.")
        print(f"Found {len(self.filesB)} GT files.")

        if not self.filesA or not self.filesB:
             print("Error: Did not find files in one or both directories.")
             self.len = 0
        else:
            self.len = min(len(self.filesA), len(self.filesB))

        if self.len == 0:
             print("Critical Error: Dataset length is 0. Cannot train.")

        print(f"Setting dataset length to: {self.len}")
        print("-----------------------")

    def __getitem__(self, index):
        if self.len == 0:
             raise IndexError("Dataset is empty, cannot get item.")
        actual_index = index % self.len
        try:
            img_A_path = self.filesA[actual_index]
            img_B_path = self.filesB[actual_index]
            img_A = Image.open(img_A_path).convert('RGB')
            img_B = Image.open(img_B_path).convert('RGB')
        except Exception as e:
            print(f"Error opening image at index {actual_index}: {e}")
            dummy_tensor = torch.zeros((3, 256, 256))
            return {"A": dummy_tensor, "B": dummy_tensor}

        if np.random.random() < 0.5:
          try:
                img_A_np = np.array(img_A)
                img_B_np = np.array(img_B)
                if len(img_A_np.shape) == 3 and len(img_B_np.shape) == 3:
                     img_A = Image.fromarray(img_A_np[:, ::-1, :], "RGB")
                     img_B = Image.fromarray(img_B_np[:, ::-1, :], "RGB")
          except Exception as e:
                print(f"Error during random flip at index {actual_index}: {e}")

        try:
            img_A = self.transform(img_A)
            img_B = self.transform(img_B)
        except Exception as e:
            print(f"Error transforming image at index {actual_index}: {e}")
            dummy_tensor = torch.zeros((3, 256, 256))
            return {"A": dummy_tensor, "B": dummy_tensor}

        return {"A": img_A, "B": img_B}

    def __len__(self):
        return self.len
# Out:
# Overwriting utils/data_utils.py

# %%
# %%writefile configs/train_MuLA-GAN.yaml
# # --- Training Configuration for MuLA-GAN on LSUI (Split) ---
# dataset_path: '/content/drive/MyDrive/LSUI_Split' # Base path to new split data
# TRAIN_INPUT: 'train/trainA'      # Relative path to blurry train
# TRAIN_GT: 'train/trainB'         # Relative path to sharp train
# TEST_INPUT: 'test/testA'         # Relative path to blurry test
# TEST_GT: 'test/testB'            # Relative path to sharp test
# dataset_name: "LSUI-Split"       # Updated dataset name
#
# # Image Info
# im_width: 256
# im_height: 256
# chans: 3
#
# # Model Info
# MODEL_NAME: 'MuLA_GAN'
# GENERATOR: 'mula_gan_g'
# DISCRIMINATOR: 'mula_gan_d'
#
# # Training Params
# BATCH_SIZE: 8           # <<< WARNING: May cause OOM. Change to 4 or 2 if needed.
# NUM_EPOCHS: 200
# LR_G: 0.0002
# LR_D: 0.0002
# B1: 0.5
# B2: 0.999
# WEIGHT_DECAY: 0.0001
# LAMBDA_L1: 100
# LAMBDA_ADV: 1
# LAMBDA_PERCEPTUAL: 10
#
# # Checkpoint/Logging Params
# ckpt_interval: 20
# SAMPLE_INTERVAL: 1000
# LOG_INTERVAL: 50
# val_interval: 1000
#
# # Output Paths
# CHECKPOINT_DIR: 'checkpoints'
# SAMPLE_DIR: 'samples'
# RESULTS_PATH: 'results'
# Out:
# Overwriting configs/train_MuLA-GAN.yaml

# %%
# !python train_MuLA_GAN.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:02<00:00, 196MB/s]
# @@@@@@@@@@@@@@
# --- Dataloader Init ---
# Base Path (from config): /content/drive/MyDrive/LSUI_Split
# Constructed Input Path: /content/drive/MyDrive/LSUI_Split/train/trainA
# Constructed GT Path: /content/drive/MyDrive/LSUI_Split/train/trainB
# Found 3424 input files.
# Found 3424 GT files.
# Setting dataset length to: 3424
# -----------------------
# /content/MuLA_GAN/train_MuLA_GAN.py:111: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   valid = Variable(Tensor(np.ones((imgs_distorted.size(0), *patch))), requires_grad=False)
# [Epoch 300/301: batch 1700/1712] [DLoss: 0.730, GLoss: 2.230, AdvLoss: 1.069]

# %%
# --- IMPORTANT: ---
# 1. Change 'LSUI-Split' if your checkpoint folder is different.
# 2. Change 'generator_199.pth' to the final generator file you found.

# !python test.py \
  --weights_path "checkpoints/LSUI-Split/generator_300.pth" \
  --data_dir "/content/drive/My Drive/LSUI_Split/test/testA/" \
  --sample_dir "./output_lsui/"
# Out:
# Loaded model from checkpoints/LSUI-Split/generator_300.pth
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/0.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1010.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1027.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1028.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1030.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1041.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1042.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1045.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1052.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1077.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1083.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1089.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1093.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1095.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1096.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1100.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1106.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1111.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1113.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1118.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/112.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1138.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1147.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1156.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1158.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/116.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1170.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1172.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1173.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1182.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1189.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/119.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1192.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1197.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/12.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1212.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1223.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1224.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1226.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1227.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1233.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1234.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1235.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1236.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1238.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1240.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1250.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1257.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1263.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1265.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1279.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/128.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1283.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1284.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1289.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1292.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1293.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1297.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1300.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/131.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1311.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1317.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1319.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1326.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1327.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1332.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1338.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1340.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1347.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/135.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1361.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1365.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1370.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/138.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1383.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1384.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1387.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1389.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1393.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1394.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1398.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1399.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/140.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1405.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1414.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1416.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/143.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/144.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1443.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1452.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1453.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1456.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1457.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/146.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1460.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1462.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1463.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1464.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1471.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1472.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1478.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/148.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1482.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1490.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1492.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1493.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1495.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1496.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/15.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1500.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1508.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1510.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1515.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1520.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1522.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1523.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/153.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1532.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1535.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1537.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1552.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1554.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1560.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1561.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1575.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1577.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1583.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1591.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1599.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1603.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1605.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1609.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1616.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1618.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1624.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1626.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1629.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1637.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1638.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1642.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1645.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1647.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1651.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1653.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1661.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1670.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1671.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1675.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1690.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1693.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1694.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1698.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/17.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1701.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1711.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1714.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1717.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1719.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1721.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1725.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1734.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1736.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1738.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1745.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1747.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/175.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1757.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1763.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1765.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1766.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1767.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/177.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1775.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1776.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1779.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1785.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1786.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1789.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1814.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1826.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/183.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1833.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1861.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1870.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1880.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1884.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1886.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1889.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1890.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1891.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1892.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1897.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1909.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1914.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1922.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1923.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/193.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1932.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1933.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/194.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1945.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/195.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1951.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1952.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1966.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/197.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1977.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1979.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1981.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/1999.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/20.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/200.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2002.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2010.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2018.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2023.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2028.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2030.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2031.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2032.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2038.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2048.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2054.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2055.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2057.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2063.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2069.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2072.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2081.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2086.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2094.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2096.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2097.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2100.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2104.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2105.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2110.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2121.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2123.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/213.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2132.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2135.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2136.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2139.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2141.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2142.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2144.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2145.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2148.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2155.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2156.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2158.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2160.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2163.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2164.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/217.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2174.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2186.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2199.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2200.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2201.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2203.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2215.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2222.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2224.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2225.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2228.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2235.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2236.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2244.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2249.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2253.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2255.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2259.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2263.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2269.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2275.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2278.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2284.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2287.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/229.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2291.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2301.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2304.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2308.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2311.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2315.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2320.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2322.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2323.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2327.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2332.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2334.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2337.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2340.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2350.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2352.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2356.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2358.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/236.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2361.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/237.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2371.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2375.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2376.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2380.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2382.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2389.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2401.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2410.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2419.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/242.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2420.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2429.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2432.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2434.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2435.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2456.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2464.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2466.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2483.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2484.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2497.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2498.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2502.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2504.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2505.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2513.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2515.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/252.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2525.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2526.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/253.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2532.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2538.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2539.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2543.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2548.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2553.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2557.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2563.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2577.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2592.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2596.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/260.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2601.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2602.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2618.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/262.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2625.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2628.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2631.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2636.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2641.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2657.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2659.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2668.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/267.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2671.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2673.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2674.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2675.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2677.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2686.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/269.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2694.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2695.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2697.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/27.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2700.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2702.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2721.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2732.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2734.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2736.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2758.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2762.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2766.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2774.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2784.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2785.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2789.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2791.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2809.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2810.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2817.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2822.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2827.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/284.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2847.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2855.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2858.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2869.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2872.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2876.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2883.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2888.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2896.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/290.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2906.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2908.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/291.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2913.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2921.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2935.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2942.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2945.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2946.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2953.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2954.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2968.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/297.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2974.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2978.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2982.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2988.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2989.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/2992.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/30.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3005.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3014.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3017.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3022.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3024.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3032.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3034.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3037.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3041.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3043.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3061.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3065.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3066.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3067.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3072.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3075.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3080.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3086.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3087.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3088.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3097.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3109.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3118.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3122.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3127.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3129.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3132.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3133.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3144.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3151.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3152.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3157.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3162.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3165.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3169.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3170.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3174.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3181.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3186.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3188.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3193.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3194.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3196.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3197.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3205.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/321.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3210.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3211.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3217.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3219.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/322.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3223.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3228.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3234.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3235.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3240.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3247.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/326.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3261.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3266.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3269.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3277.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3283.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3286.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3300.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3303.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3309.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3310.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3314.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3315.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3318.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/332.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3324.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3325.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3333.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3337.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3338.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3341.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3344.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3362.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3363.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3366.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3367.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3369.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3372.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3373.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/338.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3382.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3385.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3390.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3403.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3407.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3408.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3409.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/341.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3410.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3411.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3415.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/342.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3427.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3428.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3429.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3435.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3445.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3450.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3457.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3459.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3466.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3470.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3475.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3481.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3482.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3488.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3489.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3491.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3508.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3520.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3521.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/353.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3536.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3541.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3545.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3549.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3555.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3557.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3564.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3579.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/358.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3584.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3592.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3597.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/36.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3603.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3606.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3613.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/362.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3622.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3627.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/363.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3635.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3636.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3639.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3642.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3644.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/365.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3650.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3655.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3657.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3659.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3663.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3664.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3665.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3669.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/367.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3676.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3677.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3678.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3682.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3685.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3694.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3698.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3700.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3708.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3709.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3713.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/372.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3726.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/373.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3730.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3734.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3750.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3759.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3763.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3768.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/378.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3784.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3786.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3789.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3794.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3796.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3797.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/380.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3801.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3803.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3806.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3808.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3811.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3814.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3819.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3820.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3826.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3829.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3837.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3841.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3847.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/385.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3850.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3852.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3870.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3890.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3891.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3901.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3902.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3904.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3905.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3908.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3915.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3916.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/392.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3922.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3923.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/393.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3931.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3934.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3935.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3937.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3944.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3952.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3967.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3969.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/397.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3971.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3974.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3979.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3980.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3981.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3983.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3985.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3987.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3988.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/3990.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/40.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4000.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4001.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/401.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4014.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4017.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4020.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4029.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4034.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4050.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4052.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/406.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4066.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4069.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4073.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4085.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4094.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4103.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4104.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4108.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4117.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4119.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4125.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4127.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4128.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4132.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4138.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/414.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4140.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4142.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4146.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4148.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4149.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4158.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4160.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4162.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4166.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4172.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/418.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4189.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/42.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/422.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/429.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/43.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/433.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/437.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/438.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/440.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/444.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/448.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/452.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/454.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/460.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/48.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/481.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/483.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/487.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/489.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/49.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/491.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4918.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4924.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4925.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4933.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4934.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4937.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4939.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4941.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4949.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4950.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4954.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4956.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4958.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4965.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4968.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4978.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4983.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4985.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4989.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4990.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4993.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/4995.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5000.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5003.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5006.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5007.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5015.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5017.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5025.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5031.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5033.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/5038.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/518.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/52.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/534.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/541.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/544.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/548.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/549.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/555.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/557.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/558.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/561.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/565.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/571.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/574.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/579.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/581.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/582.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/587.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/59.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/599.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/604.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/605.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/609.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/61.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/623.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/626.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/63.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/634.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/640.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/643.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/644.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/659.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/664.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/672.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/675.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/679.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/690.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/691.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/702.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/71.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/711.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/712.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/713.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/715.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/72.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/729.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/73.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/730.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/737.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/741.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/744.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/745.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/753.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/762.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/774.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/777.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/78.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/780.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/781.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/784.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/787.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/798.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/799.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/805.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/81.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/813.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/817.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/823.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/824.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/825.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/826.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/827.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/837.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/844.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/848.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/851.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/853.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/859.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/862.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/872.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/876.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/88.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/883.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/889.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/894.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/896.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/898.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/9.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/905.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/907.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/91.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/914.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/920.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/922.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/928.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/929.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/934.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/937.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/943.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/950.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/952.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/958.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/960.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/969.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/97.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/98.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/984.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/985.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/987.jpg
# Tested: /content/drive/My Drive/LSUI_Split/test/testA/994.jpg
#
# Total samples: 855
# Time taken: 6 sec at 123.599 fps
# Saved generated images in in ./output_lsui/

# %%
# %%writefile Evaluation/measure_ssim_psnr.py
"""
# > Script for measuring quantitative performances in terms of
#   - Structural Similarity Metric (SSIM)
#   - Peak Signal to Noise Ratio (PSNR)
# > Maintainer: https://github.com/xahidbuffon
"""
## python libs
import numpy as np
from PIL import Image
from glob import glob
from os.path import join, exists # Added exists
from ntpath import basename
import os
## local libs
try:
    from Evaluation.imqual_utils import getSSIM, getPSNR
except ImportError:
    try:
         from imqual_utils import getSSIM, getPSNR
    except ImportError as e:
        print(f"Error importing imqual_utils: {e}")
        exit()

## compares avg ssim and psnr
def SSIMs_PSNRs(gtr_dir, gen_dir, im_res=(256, 256)):
    gtr_paths = sorted(glob(join(gtr_dir, "*.*")))
    print(f"Found {len(gtr_paths)} potential ground truth images in: {gtr_dir}")
    print(f"Looking for corresponding generated images in: {gen_dir}")
    ssims, psnrs = [], []
    processed_count = 0
    if not gtr_paths:
        print(f"Error: No image files found in ground truth directory: {gtr_dir}")
        return np.array([]), np.array([])
    for gtr_path in gtr_paths:
        gtr_f_base = basename(gtr_path).split('.')[0]
        gen_path_expected_png = join(gen_dir, gtr_f_base + ".png")
        gen_path_expected_jpg = join(gen_dir, gtr_f_base + ".jpg")
        gen_path_expected_jpeg = join(gen_dir, gtr_f_base + ".jpeg")
        gen_path = None
        if exists(gen_path_expected_png): gen_path = gen_path_expected_png
        elif exists(gen_path_expected_jpg): gen_path = gen_path_expected_jpg
        elif exists(gen_path_expected_jpeg): gen_path = gen_path_expected_jpeg
        if gen_path:
            processed_count += 1
            try:
                r_im = Image.open(gtr_path).resize(im_res)
                g_im = Image.open(gen_path).resize(im_res)
                if r_im.mode != 'RGB': r_im = r_im.convert('RGB')
                if g_im.mode != 'RGB': g_im = g_im.convert('RGB')
                ssim_val = getSSIM(np.array(r_im), np.array(g_im))
                if np.isfinite(ssim_val): ssims.append(ssim_val)
                r_im_L = r_im.convert("L")
                g_im_L = g_im.convert("L")
                psnr_val = getPSNR(np.array(r_im_L), np.array(g_im_L))
                if np.isfinite(psnr_val): psnrs.append(psnr_val)
            except Exception as e:
                 print(f"Error processing {basename(gtr_path)}: {e}")
    if processed_count == 0:
        print("\nError: No matching image pairs found.")
        return np.array([]), np.array([])
    return np.array(ssims), np.array(psnrs)

# --- Define YOUR paths here ---
gtr_dir = "/content/drive/MyDrive/LSUI_Split/test/testB/"  # <<< Path to LSUI test ground truth
gen_dir = "./output_lsui/"                                # <<< Path to your generated LSUI test images
# -----------------------------

### compute SSIM and PSNR
SSIM_measures, PSNR_measures = SSIMs_PSNRs(gtr_dir, gen_dir)
if len(SSIM_measures) > 0:
    print ("\n--- Results ---")
    print ("SSIM on {0} matched samples".format(len(SSIM_measures)))
    print ("Mean: {0:.4f} std: {1:.4f}".format(np.mean(SSIM_measures), np.std(SSIM_measures)))
if len(PSNR_measures) > 0:
    print ("\nPSNR on {0} matched samples".format(len(PSNR_measures)))
    print ("Mean: {0:.2f} std: {1:.2f}".format(np.mean(PSNR_measures), np.std(PSNR_measures)))
# Out:
# Overwriting Evaluation/measure_ssim_psnr.py

# %%
# !python Evaluation/measure_ssim_psnr.py
# Out:
# Found 855 potential ground truth images in: /content/drive/MyDrive/LSUI_Split/test/testB/
# Looking for corresponding generated images in: ./output_lsui/
#
# --- Results ---
# SSIM on 855 matched samples
# Mean: 0.8389 std: 0.0839
#
# PSNR on 855 matched samples
# Mean: 26.57 std: 3.85

# %%
# %%writefile Evaluation/measure_uiqm.py
"""
# > Script for measuring quantitative performance in terms of UIQM
# > Maintainer: https://github.com/xahidbuffon
"""
## python libs
import numpy as np
from PIL import Image, ImageOps
from glob import glob
from os.path import join
from ntpath import basename
import os
## local libs
try:
    from Evaluation.uqim_utils import getUIQM
except ImportError:
    try:
         from uqim_utils import getUIQM
    except ImportError as e:
        print(f"Error importing uqim_utils: {e}")
        exit()

def measure_UIQMs(dir_name, im_res=(256, 256)):
    paths = sorted(glob(join(dir_name, "*.*")))
    print(f"Found {len(paths)} files in: {dir_name}")
    uqims = []
    i=0
    if not paths:
        print(f"Error: No images found in directory: {dir_name}")
        return np.array([])
    for img_path in paths:
        i=i+1
        try:
            im = Image.open(img_path).resize(im_res)
            if im.mode != 'RGB': im = im.convert('RGB')
            im_array = np.array(im)
            uiqm = getUIQM(im_array)
            if np.isfinite(uiqm):
                 uqims.append(uiqm)
        except Exception as e:
             print(f"Error processing {basename(img_path)}: {e}")
    if not uqims:
        print("\nError: UIQM calculation failed for all images.")
        return np.array([])
    return np.array(uqims)

# --- Define YOUR path here ---
gen_dir = "./output_lsui/" # <<< Path to your generated LSUI test images
# -----------------------------

### compute UIQM
gen_uqims = measure_UIQMs(gen_dir)
if len(gen_uqims) > 0:
    print ("\n--- Results ---")
    print ("UIQM on {0} samples".format(len(gen_uqims)))
    print ("Mean: {0:.4f} std: {1:.4f}".format(np.mean(gen_uqims), np.std(gen_uqims)))
# Out:
# Overwriting Evaluation/measure_uiqm.py

# %%
# !python Evaluation/measure_uiqm.py
# Out:
# Found 855 files in: ./output_lsui/
#
# --- Results ---
# UIQM on 855 samples
# Mean: 2.8478 std: 0.3748
